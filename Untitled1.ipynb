# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
 
m = [
[1,0,2,0,0],
[1,1,1,2,0],
[0,4,1,0,0],
[0,4,4,1,2],
[1,3,0,0,1],
]
m = cv2.imread('ash.jpg',0)
plt.matshow(m[:,:])

plt.show()
